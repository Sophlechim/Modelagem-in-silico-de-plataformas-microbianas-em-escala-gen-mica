# %%
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
df = pd.read_csv('RKO_Xyl.txt', sep=";")
df
# Out:
#                                    BCPYxWYIELD  \
# 0    [0.005381986240987394, 3.581601220392587]
# 1   [0.005102936993992434, 3.5865635562019773]
# 2    [0.00515859787054137, 3.5865635562021727]
# 3     [0.005272742579908334, 3.58160122039281]
# 4     [0.005272742579908334, 3.58160122039281]
# 5    [0.005275903336838371, 3.581601220392596]
# 6     [0.004405788857415291, 3.59129344916545]
# 7     [0.004402408927331039, 3.59129344918965]
# 8   [0.0052720367743044495, 3.586563556202013]
# 9   [0.005272036774312078, 3.5865635562025204]
# 10   [0.004233309147004992, 3.591293449165559]
# 11  [0.0042889700235649395, 3.591293449165561]
# 12  [0.005155217940454958, 3.5865635561974027]
# 13   [0.004405788857430494, 3.591293449165052]
# 14  [0.0042855900934750946, 3.591293449165534]
# 15  [0.004986118160117051, 3.5865635562019604]
#
#                                                 Genes
# 0   {'R_TPI1': 0, 'R_U85_': 0, 'R_ERG12_2': 0, 'R_...
# ...

# %%
output_notebook()

xs, ys = [], []

for index, row in df.iterrows():
    a = row['BCPYxWYIELD']
    x, y = a.strip('[').strip(']').split(',')
    x = float(x)
    y = float(y)
    xs.append(x)
    ys.append(y)

p = figure(title='SPEA2 Nocaute Xilose', x_axis_label='BCPY', y_axis_label='WYIELD', plot_width=600, plot_height=600)
p.title.text_font_size = '16pt'
p.xaxis.axis_label_text_font_size = '14pt'
p.yaxis.axis_label_text_font_size = '14pt'
p.scatter(xs, ys, size=8, color="navy", alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1458">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2b6120f5-9a8d-44c1-8cc6-622b717e3418" data-root-id="1459"></div>
